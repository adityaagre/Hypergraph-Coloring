# %%
f0 = 1
f1 = 1

l=[1,1]
for x in range(2, 200):
    ans = x + (x-1)*(f0)
    l.append(ans)
    
    f0 = f1
    f1 = ans
    

    
print(l)
# Out:
# [1, 1, 3, 5, 13, 25, 71, 157, 505, 1265, 4555, 12661, 50117, 151945, 651535, 2127245, 9773041, 34035937, 166141715, 612646885, 3156692605, 12252937721, 66290544727, 269564629885, 1524682528745, 6469551117265, 38117063218651, 168208329048917, 1029160706903605, 4709833213369705, 29845660500204575, 141294996401091181, 925215475506341857, 4521439884834917825, 30532110691709281315, 153728956084387206085, 1068623874209824846061, 5534242419037939419097, 39539083345763519304295, 210301211923441697925725, 1542024250484777252867545, 8412048476937667917029041, 63222994269875867367569387, 353306036031382052515219765, 2718588753604662296805483685, 15545465585380810310669669705, 122336493912209803356246765871, 715091416927517274290804806477, 5749815213873860757743597995985, 34324388012520829165958630710945, 281740945479819177129436301803315, 1716219400626041458297931535547301, 14368788219470778033601251391969117, 89243408832554155831492439848459705, 761545775631951235780866323774363255, 4819144076
# ...

# %%
import matplotlib.pyplot as plt



plt.xlim(-10,20)
plt.ylim(0,1e3)
plt.plot(l)
plt.show()

# %%
f0 = 1
f1 = 1

l=[1,1]
for x in range(2, 10000):
    ans = x + (x-1)*(f0)
    l.append(ans)
    
    f0 = f1
    f1 = ans
    
ratios =[]
for x in range(1, len(l)):
    ratios.append(l[x] / l[x-1])
    
print()
print(max(l))
print()
print(max(ratios))
# Out:
# ...
#
# 116.64851039216998

# %%
import matplotlib.pyplot as plt



#plt.xlim(10)
##plt.ylim(0,1e3)
plt.plot(ratios)
plt.show()


## even pe neeche aata hai aur odd pe upar
